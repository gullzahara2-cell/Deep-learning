# %% [markdown]
# # Convolutionary Neural Network Model for Vehicle Classification

# %% [markdown]
# 1.  A CNN scans the image in small patches (filters) to detect simple patterns first — edges, colors, and textures.
#
# 2. Each layer stacks on the previous one, combining simple patterns into more complex shapes — wheels, windows, wings — the deeper you go.
#
# 3. At the end, it takes all these learned features and votes on which class (car, bus, bicycle, etc.) they most likely belong to.

# %%
# %pip install tensorflow kagglehub pillow matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.13/dist-packages (2.20.0)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.13/dist-packages (1.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from tensorflow) (26.3)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (1.83.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.13/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.13/dist-packages (from kagglehub) (0.1.37)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from astunparse>=1.6.0->tensorflow) (0.48.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.13/dist-packages (from keras>=3.10.0->tensorflow) (0.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %% [markdown]
# ## Dataset Link from Kaggle
#
# https://www.kaggle.com/datasets/mmohaiminulislam/vehicles-image-dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mmohaiminulislam/vehicles-image-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/1.archive...
# 100%|██████████| 1.64G/1.64G [00:14<00:00, 123MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1

# %%
import os

# Show files
for root, dirs, files in os.walk(path):
    print(root)
    print(dirs[:5])
    break
# Out:
# /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1
# ['vehicle_data']

# %%
# %ls "{path}/vehicle_data/"
# Out:
# airplane/   boat/  fire_truck/  jet_ski/     rickshaw/  skateboard/  unicycle/
# ambulance/  bus/   helicopter/  kayak/       scooter/   tractor/     van/
# bicycle/    car/   hovercraft/  motorcycle/  segway/    truck/

# %%
# %pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.6.1-py3-none-any.whl.metadata (11 kB)
# Downloading split_folders-0.6.1-py3-none-any.whl (13 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.6.1

# %%
import splitfolders
import os

# %%
input_folder = os.path.join(path, "vehicle_data")
output_folder = os.path.join(path, "split_dataset")

# %% [markdown]
# ## Splitting Dataset in 80% Trainuing, 10% Testing, 10% Validation

# %%
splitfolders.ratio(
    input=input_folder,
    output=output_folder,
    seed=42,
    ratio=(0.8, 0.1, 0.1),
    group_prefix=None,
    move=False
)
# Out:
# Copying files: 3698 files [00:09, 402.35 files/s]

# %% [markdown]
# Converting 4 Channel to 3 Channels

# %%
from PIL import Image
import os

dataset_dir = output_folder

bad = []

for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp")):
            p = os.path.join(root, file)

            try:
                img = Image.open(p)
                if img.mode != "RGB":
                    bad.append((p, img.mode))
            except Exception as e:
                bad.append((p, str(e)))

print("Bad Images:", len(bad))

for b in bad[:50]:
    print(b)
# Out:
# Bad Images: 311
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bicycle/3d28ee7b-f3f4-4b98-9099-1ff806fddd68.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bicycle/3d2980a8-a404-412d-b599-895dc1f96e55.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/van/f436090a-9a9e-4253-a90e-0aafd2d858d8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/fabe8966-b8e1-41c4-a59c-c5d8ece2edec.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/7f57d365-467e-4c25-98fb-bc28cf6ce83f.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/cb29519c-76b3-49d0-a05e-5c6748cb15ab.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/ed1fdf68-cc9f-4be6-a0ab-619a3f5b6210.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bus/37789954-ffc1-454d-b9f0-8e1048de9f01.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bus/79f54c05-12e4-477e-affd-dea2794e6e3c.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/025a5dc8-6322-49c4-8ec7-16636b76607b.jpg', 'L')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/6ee023e8-11fc-4009-b1c2-68c8b2e7082e.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/f28e479e-bc56-4d15-bb2d-05884e0e7af1.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/helicopter/4a6f6b41-69e3-433c-9e65-fa0f9806ffdc.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/3f841eaa-f2f7-4e46-809e-265510af42e9.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/6b5af22c-a330-4783-9f94-55c3ddcdf173.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/d5583536-b3d5-4479-bdb4-97694f7dfb8e.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/boat/61abd2d2-972d-4ee9-845b-3000f4ce41ca.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/boat/37d28f28-d83f-49f0-83c9-e86e2564aa6b.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/scooter/3533a2ea-6f57-4b52-8013-04270fcd1ed0.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/scooter/59b8578c-9ba1-4e14-9e41-6e93f0ad6636.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/scooter/31d4ba78-a321-41d7-baf5-695b9df77076.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/scooter/744ca683-b376-4675-946e-6b4908199a8e.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/motorcycle/fc8e4fcf-0a8a-4eca-8a65-44f3a01d87f8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/motorcycle/431252ea-871d-484f-bbff-9f88d53b92cb.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/truck/adb7ae9f-fe31-4912-b607-1467fd6c2790.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/truck/f894b582-83d3-411d-bff0-c5a2f936afd4.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/skateboard/f8c0ca15-baab-417f-b4fd-fea70f8a30d7.gif', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/ambulance/ed49182c-32a8-41f5-9f1a-a1efc965e241.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/ambulance/ee3019be-b7e7-4bfe-b1c1-aac7df78e88d.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/546e0d7a-c6b5-4e07-b12e-ec32159078e3.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/25c16813-1491-4f67-a3b6-8d4c8976e153.jpg', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/2553bb55-1467-4b92-ade8-a532eb8342fd.jpg', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/11c121ef-f1f0-4dbc-a257-cfc43bb62277.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/e7c68487-94ec-411c-94f8-9e66cc712923.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/b08ce92d-f6bd-4b79-934e-7568bdfeaee8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/bb8f3774-8bf7-4375-ad6e-d8f601f3e334.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/4d62c774-2f39-4b09-87f2-c0a9360fbd1b.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/85e54584-8bf7-4e8f-b2ca-ffe39dd3a189.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/jet_ski/5de44b08-0720-40d3-9a6c-b9613e184399.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/helicopter/e71c840c-0b96-4bba-94a1-25edfba66f01.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/helicopter/20f87069-ea1b-4721-8ff6-506f71b3198d.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/rickshaw/51fa7906-487a-44cc-b9d1-d9c24daba6c2.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/481ddc1c-772b-4ff9-bfb8-bc1e32f0defc.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/c16ba4d0-19ef-4f49-92af-2d005e47ad61.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/2a5d85b5-0961-4348-910e-8042f31fceb9.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/segway/ccb8556f-3590-48d4-bedc-61370a9e87ae.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/segway/53b6a977-4d69-40f7-ac96-9bc8772359cb.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/2c96ce5d-f71a-482d-9c2b-79be4b3d4599.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/0b8aaf2e-b93b-48fc-8ca2-0917f43f37fc.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/712e89a8-3600-4545-8602-6ae05fb6e4b2.png', 'RGBA')

# %%
from PIL import Image
import os

dataset_dir = os.path.join(path, "split_dataset")

converted = 0
failed = []

for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".webp")):
            img_path = os.path.join(root, file)

            try:
                img = Image.open(img_path)

                # Convert every non-RGB image
                if img.mode != "RGB":
                    img = img.convert("RGB")
                    img.save(img_path)
                    converted += 1

            except Exception as e:
                failed.append((img_path, str(e)))

print(f"Converted: {converted}")
print(f"Failed: {len(failed)}")

if failed:
    print(failed[:10])
# Out:
# /usr/local/lib/python3.13/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Converted: 299
# Failed: 0

# %%
for folder in ["train", "val", "test"]:
    print(f"\n{folder.upper()}")
    print(os.listdir(os.path.join(output_folder, folder))[:5])
# Out:
# TRAIN
# ['bicycle', 'van', 'unicycle', 'bus', 'tractor']
#
# VAL
# ['bicycle', 'van', 'unicycle', 'bus', 'tractor']
#
# TEST
# ['bicycle', 'van', 'unicycle', 'bus', 'tractor']

# %%
train_dir = os.path.join(output_folder, "train")
val_dir = os.path.join(output_folder, "val")
test_dir = os.path.join(output_folder, "test")

# %%
import os
import tensorflow as tf

IMG_SIZE = (128, 128)
BATCH_SIZE = 32


train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

print("Number of Classes:", len(class_names))
print("Classes:", class_names)
# Out:
# Found 2946 files belonging to 20 classes.
# Found 362 files belonging to 20 classes.
# Found 384 files belonging to 20 classes.
# Number of Classes: 20
# Classes: ['airplane', 'ambulance', 'bicycle', 'boat', 'bus', 'car', 'fire_truck', 'helicopter', 'hovercraft', 'jet_ski', 'kayak', 'motorcycle', 'rickshaw', 'scooter', 'segway', 'skateboard', 'tractor', 'truck', 'unicycle', 'van']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization,
    GlobalAveragePooling2D, Dense, Dropout, Rescaling,
    RandomFlip, RandomRotation, RandomZoom, RandomContrast,
    RandomTranslation
)
from tensorflow.keras.regularizers import l2

num_classes = len(class_names)


model = Sequential([
    Input(shape=(128, 128, 3)),

    # Augmentation
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1),

    Rescaling(1./255),

    # Block 1
    Conv2D(32, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2),

    # Block 2
    Conv2D(64, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.25),

    # Block 3
    Conv2D(128, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.3),

    # Block 4
    Conv2D(256, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.35),

    GlobalAveragePooling2D(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 128, 128, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         2,580 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 425,812 (1.62 MB)
#  Trainable params: 424,852 (1.62 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=40
)
# Out:
# Epoch 1/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 80s 167ms/step - accuracy: 0.0957 - loss: 3.0573 - val_accuracy: 0.0495 - val_loss: 4.1282
# Epoch 2/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.1392 - loss: 2.8254 - val_accuracy: 0.0521 - val_loss: 4.5815
# Epoch 3/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.1555 - loss: 2.7337 - val_accuracy: 0.0573 - val_loss: 4.7157
# Epoch 4/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.1901 - loss: 2.6752 - val_accuracy: 0.0729 - val_loss: 4.4955
# Epoch 5/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.1816 - loss: 2.6212 - val_accuracy: 0.1068 - val_loss: 3.4489
# Epoch 6/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.2145 - loss: 2.5691 - val_accuracy: 0.1510 - val_loss: 2.7108
# Epoch 7/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.2305 - loss: 2.5115 - val_accuracy: 0.2188 - val_loss: 2.5099
# Epoch 8/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.2349 - loss: 2.4640 - val_accuracy: 0.1927 - val_loss: 2.5048
# Epoch 9/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.2580 - loss: 2.4000 - val_accuracy: 0.2422 - val_loss: 2.3695
# Epoch 10/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.2651 - loss: 2.3624 - val_accuracy: 0.1953 - val_loss: 2.5287
# Epoch 11/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.2729 - loss: 2.3055 - val_accuracy: 0.2240 - val_loss: 2.4825
# Epoch 12/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.2862 - loss: 2.2761 - val_accuracy: 0.2786 - val_loss: 2.2240
# Epoch 13/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.3031 - loss: 2.2252 - val_accuracy: 0.1901 - val_loss: 2.7146
# Epoch 14/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.3133 - loss: 2.1956 - val_accuracy: 0.1562 - val_loss: 3.1548
# Epoch 15/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.3347 - loss: 2.1379 - val_accuracy: 0.2891 - val_loss: 2.2104
# Epoch 16/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.3316 - loss: 2.1128 - val_accuracy: 0.2318 - val_loss: 2.3948
# Epoch 17/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.3456 - loss: 2.1164 - val_accuracy: 0.3568 - val_loss: 2.0373
# Epoch 18/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.3730 - loss: 2.0333 - val_accuracy: 0.2604 - val_loss: 2.5308
# Epoch 19/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.3788 - loss: 1.9910 - val_accuracy: 0.2578 - val_loss: 2.5320
# Epoch 20/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.3914 - loss: 1.9510 - val_accuracy: 0.2839 - val_loss: 2.2948
# Epoch 21/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.3931 - loss: 1.9528 - val_accuracy: 0.2344 - val_loss: 2.5238
# Epoch 22/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4077 - loss: 1.8935 - val_accuracy: 0.2969 - val_loss: 2.2764
# Epoch 23/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.4145 - loss: 1.8481 - val_accuracy: 0.3073 - val_loss: 2.4090
# Epoch 24/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4352 - loss: 1.8119 - val_accuracy: 0.3542 - val_loss: 2.1444
# Epoch 25/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4406 - loss: 1.7921 - val_accuracy: 0.2578 - val_loss: 2.7413
# Epoch 26/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4386 - loss: 1.7518 - val_accuracy: 0.2760 - val_loss: 2.8224
# Epoch 27/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4535 - loss: 1.7197 - val_accuracy: 0.3073 - val_loss: 2.3953
# Epoch 28/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4630 - loss: 1.7065 - val_accuracy: 0.2734 - val_loss: 2.5587
# Epoch 29/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4749 - loss: 1.6668 - val_accuracy: 0.3724 - val_loss: 2.0968
# Epoch 30/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.4773 - loss: 1.6345 - val_accuracy: 0.2865 - val_loss: 2.7807
# Epoch 31/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4885 - loss: 1.6097 - val_accuracy: 0.2865 - val_loss: 2.6558
# Epoch 32/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.4990 - loss: 1.5944 - val_accuracy: 0.3698 - val_loss: 2.1553
# Epoch 33/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5166 - loss: 1.5493 - val_accuracy: 0.3047 - val_loss: 2.8884
# Epoch 34/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.5282 - loss: 1.5081 - val_accuracy: 0.3620 - val_loss: 2.4663
# Epoch 35/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5384 - loss: 1.4710 - val_accuracy: 0.4714 - val_loss: 1.7398
# Epoch 36/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.5390 - loss: 1.4516 - val_accuracy: 0.2995 - val_loss: 2.4664
# Epoch 37/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.5411 - loss: 1.4703 - val_accuracy: 0.3906 - val_loss: 2.0878
# Epoch 38/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.5455 - loss: 1.4149 - val_accuracy: 0.4583 - val_loss: 1.9173
# Epoch 39/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.5604 - loss: 1.3864 - val_accuracy: 0.4427 - val_loss: 2.0332
# Epoch 40/40
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.5740 - loss: 1.3678 - val_accuracy: 0.4297 - val_loss: 2.2150

# %%
loss, accuracy = model.evaluate(test_ds)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4297 - loss: 2.2150
# Test Loss: 2.2150
# Test Accuracy: 0.4297

# %%
model.save("cars_cnn.keras")

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os

def predict_image(img_path, model, class_names, img_size=128):
    # Load and resize image
    img = image.load_img(img_path, target_size=(img_size, img_size))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = np.max(predictions[0]) * 100

    # Show image with prediction
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_class} ({confidence:.2f}%) Kishan")
    plt.show()

    return predicted_class, confidence


# Usage
# Construct a valid path to a bicycle image from the test set
bicycle_test_dir = os.path.join(test_dir, 'bicycle')

# Get the first image file from that directory
image_files = os.listdir(bicycle_test_dir)
if image_files:
    sample_bicycle_image = image_files[0]
    image_path_to_predict = os.path.join(bicycle_test_dir, sample_bicycle_image)

    predict_image(image_path_to_predict, model, class_names)
else:
    print(f"No image files found in {bicycle_test_dir}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import os # Added os import

def predict_image(img_path, model, class_names, img_size=128):
    # Load and resize image
    img = image.load_img(img_path, target_size=(img_size, img_size))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = np.max(predictions[0]) * 100

    # Show image with prediction
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_class} ({confidence:.2f}%) Kishan")
    plt.show()

    return predicted_class, confidence


# Usage
# Re-define necessary path variables from the notebook's state
path = '/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1'
output_folder = os.path.join(path, "split_dataset")
test_dir = os.path.join(output_folder, "test")

# Construct a valid path to a car image from the test set
car_test_dir = os.path.join(test_dir, 'car')

# Get the first image file from that directory
image_files = os.listdir(car_test_dir)
if image_files:
    sample_car_image = image_files[0]
    image_path_to_predict = os.path.join(car_test_dir, sample_car_image)

    predict_image(image_path_to_predict, model, class_names)
else:
    print(f"No image files found in {car_test_dir}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
